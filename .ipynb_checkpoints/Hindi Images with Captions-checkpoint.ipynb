# %%
import requests

# %%
page = requests.get("http://aajtak.intoday.in/gallery/amarnath-yatra-jammu-and-kashmir-terrorist-attack-pilgrims-pakistan-2-13478.html")

# %%
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())

# %%
# Out:
# <!-- 223 ----133 -->
# <!-- 223 ----133 -->
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://smedia2.intoday.in/aajtak/resources/theme_v2/images/favicon.ico" rel="shortcut icon"/>
#   <meta content="INDEX, FOLLOW" name="ROBOTS"/>
#   <title>
#    कहीं जलाए पुतले, तो कहीं सड़कें रोकीं, ऐसे दिखा आतंक के खिलाफ लोगों का गुस्सा - India Gallery AajTak  - photo 2
#   </title>
#   <meta content="सावन के पावन अवसर पर कश्मीर के पास अनंतनाग होते हुए अमरनाथ यात्री अमरनाथ के दर्शन के लिए जा रहे थे. तभी बीच में अनंतगांव में  - photo 2" name="description"/>
#   <meta content="must-revalidate" http-equiv="cache-control"/>
#   <meta content="hi" name="dc.language">
#    <link href="https://m.aajtak.in/national/gallery/amarnath-yatra-jammu-and-kashmir-terrorist-attack-pilgrims-pakistan-13478-2017-07-11" media="only screen and (max-width: 640px)" rel="alternate"/>
#    <script type="text/javascript">
# ...

# %%
list(soup.children)
# Out:
# [u' 121 ----121 ',
#  u'doctype html',
#  u'\n',
# ...

# %%
x = [type(item) for item in list(soup.children)] 
print x
# Out:
# [<class 'bs4.element.Comment'>, <class 'bs4.element.Doctype'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Tag'>, <class 'bs4.element.NavigableString'>]

# %%
html = list(soup.children)[3]
list(html.children)
# Out:
# [<head><meta charset="unicode-escape"/>\n<link href="https://smedia2.intoday.in/aajtak/resources/theme_v2/images/favicon.ico" rel="shortcut icon"/>\n<meta content="INDEX, FOLLOW" name="ROBOTS"/>\n<title>\u092a\u0941\u0930\u093e\u0928\u093e \u0939\u0948 \u092a\u0941\u0924\u093f\u0928 \u0915\u093e \u0921\u0949\u0917 \u0938\u0947 \u092a\u094d\u092f\u093e\u0930, \u090f\u0902\u091c\u0947\u0932\u093e \u092d\u0940 \u0926\u0947\u0916 \u0915\u0930 \u0917\u0908 \u0925\u0940\u0902 \u0918\u092c\u0930\u093e - World AajTak</title> <meta content="\u0930\u0942\u0938\u0940 \u0930\u093e\u0937\u094d\u091f\u094d\u0930\u092a\u0924\u093f \u0935\u094d\u0932\u093e\u0926\u093f\u092e\u0940\u0930 \u092a\u0941\u0924\u093f\u0928 \u0915\u094b \u0924\u0941\u0930\u094d\u0915\u092e\u0947\u0928\u093f\u0938\u094d\u0924\u093e\u0928 \u0915\u0947 \u0928\u0947\u0924\u093e \u0928\u0947 \u092c\u0941\u0927\u0935\u093e\u0930 \u0915\u094b \u0909\u0928\u094d\u0939\u0947\u0902 \u091c\u0928\u094d\u092e\u0926\u093f\u0928 \u0909\u0
# ...

# %%
soup.find_all("div",{"Class":"SliderImagesSec"})
# Out:
# []

# %%
from pprint import pprint
import re

# %%
for i in soup.find_all(attrs={"id" : re.compile("slide"),"class":"img_container"}):
    print i.p
    print i.img
# print (re.compile('^slide'))
# soup.select()
# Out:
# <p>जम्मू कश्मीर में सोमवार को अमरनाथ यात्रियों पर बड़ा आतंकी हमला हुआ है. जम्मू कश्मीर के अनंतनाग में हुए इस हमले में सात 7 श्रद्धालुओं की मौत हो गई है. जबकि 19 यात्री घायल हैं. एक तरफ जहां इस हमले के बाद सुरक्षा व्यवस्था पर सवाल खड़े कर दिए हैं. तो वहीं पूरा देश गुस्से में है.</p>
# <img alt="कहीं जलाए पुतले, तो कहीं सड़कें रोकीं, ऐसे दिखा आतंक के खिलाफ लोगों का गुस्सा" src="https://smedia2.intoday.in/aajtak/images/Photo_gallery/072017/india-kashmir-pilgrim_josh1_071117032344.jpg"/>
# <p>सावन के पावन अवसर पर कश्मीर के पास अनंतनाग होते हुए अमरनाथ यात्री अमरनाथ के दर्शन के लिए जा रहे थे. तभी बीच में अनंतगांव में आतंकियों ने हमला कर दिया. सोमवार रात को आतंकियों ने यात्रियों को लेकर लौट रही बस पर फायरिंग कर दी.</p>
# <img alt="कहीं जलाए पुतले, तो कहीं सड़कें रोकीं, ऐसे दिखा आतंक के खिलाफ लोगों का गुस्सा" src="https://smedia2.intoday.in/aajtak/images/Photo_gallery/072017/amarnath-8_071117033110.jpg"/>
# ...

# %%
page2 = requests.get("http://aajtak.intoday.in/photos/sports.html")

# %%
soup2 = BeautifulSoup(page.content, 'html.parser')
print(soup2.prettify())
# Out:
# <!-- 223 ----133 -->
# <!-- 223 ----133 -->
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://smedia2.intoday.in/aajtak/resources/theme_v2/images/favicon.ico" rel="shortcut icon"/>
#   <meta content="INDEX, FOLLOW" name="ROBOTS"/>
#   <title>
#    कहीं जलाए पुतले, तो कहीं सड़कें रोकीं, ऐसे दिखा आतंक के खिलाफ लोगों का गुस्सा - India Gallery AajTak  - photo 2
#   </title>
#   <meta content="सावन के पावन अवसर पर कश्मीर के पास अनंतनाग होते हुए अमरनाथ यात्री अमरनाथ के दर्शन के लिए जा रहे थे. तभी बीच में अनंतगांव में  - photo 2" name="description"/>
#   <meta content="must-revalidate" http-equiv="cache-control"/>
#   <meta content="hi" name="dc.language">
#    <link href="https://m.aajtak.in/national/gallery/amarnath-yatra-jammu-and-kashmir-terrorist-attack-pilgrims-pakistan-13478-2017-07-11" media="only screen and (max-width: 640px)" rel="alternate"/>
#    <script type="text/javascript">
# ...
